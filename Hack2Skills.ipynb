# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

BASE_URL = "https://www.yellowpages.com/search?search_terms=IT+Services&geo_location_terms=California"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

company_data = []

def scrape_page(url):
    """Scrapes a single page for company data."""
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Finding all company blocks on the page
        companies = soup.find_all('div', class_='result')
        for company in companies:
            try:
                name = company.find('a', class_='business-name').text.strip()
            except AttributeError:
                name = None
            
            try:
                website = company.find('a', class_='track-visit-website')['href']
            except (AttributeError, TypeError):
                website = None

            try:
                contact = company.find('div', class_='phones phone primary').text.strip()
            except AttributeError:
                contact = None

            try:
                address = company.find('p', class_='adr').text.strip()
            except AttributeError:
                address = None

            try:
                category = company.find('div', class_='categories').text.strip()
            except AttributeError:
                category = None

            try:
                description = company.find('div', class_='snippet').text.strip()
            except AttributeError:
                description = None

            try:
                email = None 
            except AttributeError:
                email = None

            # Adding the data to the list
            company_data.append({
                "Company Name": name,
                "Website URL": website,
                "Contact Number": contact,
                "Location/Address": address,
                "Industry/Category": category,
                "Company Description": description,
                "Email Address": email
            })

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the page: {e}")

# Scrape first 3 pages
for page in range(1, 4):
    print(f"Scraping page {page}...")
    url = f"{BASE_URL}&page={page}"
    scrape_page(url)
    time.sleep(2)

# Saving the data to a CSV file
df = pd.DataFrame(company_data)
df.to_csv('company_data2.csv', index=False)
print("Data saved to company_data2.csv")
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Data saved to company_data2.csv

# %%
df=pd.read_csv("company_data2.csv")

# %%
df
# Out:
#                                     Company Name  \
# 0                                  Geeks On Site
# 1                    T & T Truck & Crane Service
# 2                    Waters Vacuum Truck Service
# 3                        Gastelums' Tree Service
# 4               Ernie's Plumbing & Sewer Service
# ..                                           ...
# 86      Team Insurance & Financial Services Inc.
# 87                          Roy's Screen Service
# 88  JC  Pressure Washing &  Landscaping Services
# 89                 Nationwide Transport Services
# 90                   Sunshine Janitorial Service
#
#                                  Website URL  Contact Number  \
# 0                                        NaN             NaN
# 1                   http://truckandcrane.com  (805) 232-5116
# 2               https://www.watersvacuum.com  (775) 276-6124
# 3         http://www.gastelumtreeservice.com  (707) 435-3072
# 4      http://www.erniesplumbingandsewer.com  (707) 515-7550
# ..                                       ...             ...
# 86                 https://teaminsurance.net  (707) 462-5901
# 87              https://roysmobilescreen.com  (424) 253-8244
# 88                                       NaN  (916) 396-4718
# 89                  https://ntslogistics.com  (844) 684-7608
# 90  http://www.sunshinejanitorialservice.net  (909) 500-2323
#
#       Location/Address                                  Industry/Category  \
# 0   Serving your area.    Computers & Computer Equipment-Service & Repair
# 1                  NaN  Trucking-Heavy HaulingCranes-Renting & Leasing...
# 2   Serving theCA Area  Septic Tank & System CleaningPlumbing-Drain & ...
# 3                  NaN            Landscaping & Lawn ServicesTree Service
# 4   Serving theCA Area  Building ContractorsPlumbersPlumbing-Drain & S...
# ..                 ...                                                ...
# 86                 NaN  Life InsuranceHealth InsuranceHomeowners Insur...
# 87  Serving theCA Area  Screen EnclosuresScreening & Sifting Equipment...
# 88                 NaN  Power WashingLandscape ContractorsPressure Was...
# 89  Serving theCA Area  Container Freight ServiceTrucking Transportati...
# 90  Serving theCA Area    Window CleaningJanitorial ServiceHouse Cleaning
#
#                                   Company Description  Email Address
# 0                                                 NaN            NaN
# 1   From Business: T&T Truck and Crane Service is ...            NaN
# 2   The crew at Waters are the best!  My old septi...            NaN
# 3   From Business: Are you looking for a quality t...            NaN
# 4   George was a employee that any company would b...            NaN
# ..                                                ...            ...
# 86                     good service  and information"            NaN
# 87  From Business: Proudly serving West Los Angele...            NaN
# 88  From Business: JC Pressure Washing & Landscapi...            NaN
# 89  I am really happy with the services, great tea...            NaN
# 90  From Business: Sunshine Janitorial Service off...            NaN
#
# [91 rows x 7 columns]

# %%
# Out:
# Data saved to yellow_pages_data.csv

# %%
# Out:
#                                        Company Name  \
# 0                                     Geeks On Site
# 1                       T & T Truck & Crane Service
# 2                       Waters Vacuum Truck Service
# 3                           Gastelums' Tree Service
# 4                  Ernie's Plumbing & Sewer Service
# ..                                              ...
# 56  Carlon's Fire Extinguisher Sales & Service Inc.
# 57                         County RV Service Center
# 58                  Redwood Trust Deed Services Inc
# 59                           J&J TV Sales & Service
# 60                    Cal Communication Service Inc
#
#                               Website URL  Contact Number  \
# 0                                     NaN             NaN
# 1                http://truckandcrane.com  (805) 232-5116
# 2            https://www.watersvacuum.com  (775) 276-6124
# 3      http://www.gastelumtreeservice.com  (707) 435-3072
# 4   http://www.erniesplumbingandsewer.com  (707) 515-7550
# ..                                    ...             ...
# 56      https://www.carlonsfiresafety.com  (844) 238-6974
# 57               https://www.countyrv.com  (619) 440-6688
# 58        http://www.redwoodtrustdeed.com  (800) 378-4388
# 59             https://www.jjtvrepair.com  (562) 222-8083
# 60                  http://www.calcsc.com  (925) 237-1907
#
#                   Location/Address  \
# 0                              NaN
# 1            1375 N Olive St Ste A
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 56                             NaN
# 57              10229 Prospect Ave
# 58    3550 Round Barn Blvd Ste 203
# 59              9209 Whittier Blvd
# 60  2624 Verne Roberts Cir Ste 101
#
#                                     Industry/Category  Company Description
# 0     Computers & Computer Equipment-Service & Repair                  NaN
# 1   Trucking-Heavy HaulingCranes-Renting & Leasing...                  NaN
# 2   Septic Tank & System CleaningPlumbing-Drain & ...                  NaN
# 3             Landscaping & Lawn ServicesTree Service                  NaN
# 4   Building ContractorsPlumbersPlumbing-Drain & S...                  NaN
# ..                                                ...                  ...
# 56  Fire Protection Equipment & SuppliesFire Prote...                  NaN
# 57  Trailer Equipment & PartsRecreational Vehicles...                  NaN
# 58                               Foreclosure Services                  NaN
# 59  Television & Radio-Service & RepairTelevision ...                  NaN
# 60  FireproofingFire Protection Equipment & Suppli...                  NaN
#
# [61 rows x 6 columns]
